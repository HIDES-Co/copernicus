# %%
import openeo
import json
import folium

# %%
connection = openeo.connect("openeo.vito.be")
# Get all collection ids
connection.list_collection_ids()
# Get metadata of a single collection
connection.describe_collection("TERRASCOPE_S5P_L3_CH4_TD")
# Out:
# {'assets': {'metadata_iso_19139': {'href': 'https://services.terrascope.be/collectioncatalogue/srv/api/records/urn:eop:VITO:TERRASCOPE_S5P_L3_CH4_TD_V2/formatters/xml?approved=true',
#    'roles': ['metadata', 'iso-19139'],
#    'title': 'ISO 19139 metadata',
#    'type': 'application/vnd.iso.19139+xml'},
#   'thumbnail': {'href': 'https://services.terrascope.be/collectioncatalogue/images/quicklooks/S5P_CH4_TD.png',
#    'roles': ['thumbnail'],
#    'title': 'Thumbnail',
#    'type': 'image/png'}},
#  'cube:dimensions': {'bands': {'type': 'bands', 'values': ['CH4', 'weight']},
#   't': {'extent': ['2018-07-01T00:00:00Z', None], 'type': 'temporal'},
#   'x': {'axis': 'x',
#    'extent': [-180.0, 180.0],
#    'step': 0.05,
#    'type': 'spatial'},
#   'y': {'axis': 'y',
#    'extent': [-89.0, 89.0],
#    'step': 0.05,
#    'type': 'spatial'}},
# ...
